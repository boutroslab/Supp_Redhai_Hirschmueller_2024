# %%
import pandas as pd
from IPython.display import Image

# %%
# Test
# !pyGenomeTracks --tracks tracks.ini --region chrX:7102987-7276668 --outFileName ../results/trackplots/test.png
# Out:
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 23/23 [00:00<00:00, 36103.66it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 7307.15it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 28/28 [00:00<00:00, 39225.29it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 34/34 [00:00<00:00, 1818.70it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 84/84 [00:00<00:00, 1970.13it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.2061424255371094
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 7.9799999999999995,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (7.9799999999999995, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 17.18,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (17.18, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]

# %%
Image(filename='../results/trackplots/test.png')

# %%
# Create a bed file with relative window around genes
bed = pd.read_csv("../resources/genes/genes.bed", sep="\t", header=None)
bed.columns = ["chrom", "start", "end", "name"]
window_scale = 1/3  # gene length * window_scale
window = ((bed['end'] - bed['start']) * window_scale).astype(int)
bed['start'] = bed['start'] - window
bed['end'] = bed['end'] + window
bed.to_csv(f"../resources/genes/genes_relative_window.bed", sep="\t", header=None, index=None)

# %%
# read windowed bed file
bed = pd.read_csv("../resources/genes/genes_relative_window.bed", sep="\t", header=None)
bed.columns = ["chrom", "start", "end", "name"]
for i, row in bed.iterrows():
    # !pyGenomeTracks --tracks tracks.ini --region {row["chrom"]}:{row["start"]}-{row["end"]} --outFileName ../results/trackplots/CHIPseq_scute_trackplot_for_{row["name"]}.pdf
# Out:
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 23/23 [00:00<00:00, 35130.73it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 6909.89it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 28/28 [00:00<00:00, 48269.84it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 34/34 [00:00<00:00, 1796.34it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 84/84 [00:00<00:00, 1942.39it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:4.009472370147705
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 7.9799999999999995,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (7.9799999999999995, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 17.18,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (17.18, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 33/33 [00:00<00:00, 25074.64it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 100%|██████████████████████████████████████████| 2/2 [00:00<00:00, 13797.05it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 67/67 [00:00<00:00, 26917.47it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 58/58 [00:00<00:00, 2315.60it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|███████████████████████████████████████| 105/105 [00:00<00:00, 2106.31it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.409636974334717
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 14.879999999999999,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (14.879999999999999, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 30.979999999999997,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (30.979999999999997, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|██████████████████████████████████████████| 9/9 [00:00<00:00, 23402.81it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 9754.20it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 14/14 [00:00<00:00, 36024.70it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 57/57 [00:00<00:00, 2213.35it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 96/96 [00:00<00:00, 1583.14it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.075756311416626
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 5.68,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (5.68, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 10.28,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (10.28, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 15/15 [00:00<00:00, 28519.75it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 7724.32it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 20/20 [00:00<00:00, 34836.41it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 1158.98it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 83/83 [00:00<00:00, 1272.46it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.374584197998047
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 3.38,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (3.38, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 21.78,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (21.78, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 47/47 [00:00<00:00, 41712.29it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 100%|██████████████████████████████████████████| 2/2 [00:00<00:00, 11602.50it/s]
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 45/45 [00:00<00:00, 39510.92it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 41/41 [00:00<00:00, 2225.53it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 92/92 [00:00<00:00, 2046.21it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.183180093765259
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 26.379999999999995,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (26.379999999999995, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 63.17999999999999,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (63.17999999999999, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 27/27 [00:00<00:00, 21314.93it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 0it [00:00, ?it/s]
# WARNING:pygenometracks.utilities:No valid intervals were found in file /scratch/peidli/DECODE_cph/macs2/SRR3845161_peaks.narrowPeak after intersection with the plotted region
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 36/36 [00:00<00:00, 33229.52it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████|
-0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 7839.82it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 0it [00:00, ?it/s]
# WARNING:pygenometracks.utilities:No valid intervals were found in file /scratch/peidli/DECODE_cph/macs2/SRR3845161_peaks.narrowPeak after intersection with the plotted region
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|██████████████████████████████████████████| 5/5 [00:00<00:00, 17593.56it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 36/36 [00:00<00:00, 2199.84it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 72/72 [00:00<00:00, 2015.12it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.115596294403076
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# No interval was found when overlapping with both chrX:11581218-11584914 and X:11581218-11584914 inside the bedgraph file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 3.38,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (3.38, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 5.68,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (5.68, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 6584.46it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 0it [00:00, ?it/s]
# WARNING:pygenometracks.utilities:No valid intervals were found in file /scratch/peidli/DECODE_cph/macs2/SRR3845161_peaks.narrowPeak after intersection with the plotted region
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 7710.12it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 26/26 [00:00<00:00, 1031.63it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 74/74 [00:00<00:00, 1501.49it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.208608627319336
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# No interval was found when overlapping with both chr3R:5235685-5237722 and 3R:5235685-5237722 inside the bedgraph file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 3.38,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (3.38, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 3.38,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (3.38, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 18409.53it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 0it [00:00, ?it/s]
# WARNING:pygenometracks.utilities:No valid intervals were found in file /scratch/peidli/DECODE_cph/macs2/SRR3845161_peaks.narrowPeak after intersection with the plotted region
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|██████████████████████████████████████████| 8/8 [00:00<00:00, 21426.84it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 38/38 [00:00<00:00, 2052.30it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 72/72 [00:00<00:00, 2246.40it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.2661595344543457
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# No interval was found when overlapping with both chr2R:9749757-9769458 and 2R:9749757-9769458 inside the bedgraph file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 5.68,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (5.68, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 10.28,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (10.28, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
# INFO:pygenometracks.tracksClass:initialize 1. [Coverage1]
# INFO:pygenometracks.tracksClass:initialize 2. [Coverage2]
# INFO:pygenometracks.tracksClass:initialize 3. [spacer]
# INFO:pygenometracks.tracksClass:initialize 4. [Peak1]
# 100%|████████████████████████████████████████| 14/14 [00:00<00:00, 21168.08it/s]
# INFO:pygenometracks.tracksClass:initialize 5. [Peak2]
# 0it [00:00, ?it/s]
# WARNING:pygenometracks.utilities:No valid intervals were found in file /scratch/peidli/DECODE_cph/macs2/SRR3845161_peaks.narrowPeak after intersection with the plotted region
# INFO:pygenometracks.tracksClass:initialize 6. [Peakvs]
# 100%|████████████████████████████████████████| 12/12 [00:00<00:00, 28976.19it/s]
# INFO:pygenometracks.tracksClass:initialize 7. [spacer]
# INFO:pygenometracks.tracksClass:initialize 8. [genes]
# 100%|█████████████████████████████████████████| 27/27 [00:00<00:00, 2112.33it/s]
# INFO:pygenometracks.tracksClass:initialize 9. [transcripts]
# 100%|█████████████████████████████████████████| 44/44 [00:00<00:00, 2050.00it/s]
# INFO:pygenometracks.tracksClass:initialize 10. [x-axis]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:3.4284448623657227
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 21.542553191489365. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [Coverage1]
# INFO:pygenometracks.tracksClass:plotting 2. [Coverage2]
# INFO:pygenometracks.tracksClass:plotting 3. [spacer]
# INFO:pygenometracks.tracksClass:plotting 4. [Peak1]
# INFO:pygenometracks.tracksClass:plotting 5. [Peak2]
# WARNING:pygenometracks.tracks.GenomeTrack:*Warning*
# No interval was found when overlapping with both chr3R:31059202-31089458 and 3R:31059202-31089458 inside the bedgraph file. This will generate an empty track!!
#
# INFO:pygenometracks.tracksClass:plotting 6. [Peakvs]
# INFO:pygenometracks.tracksClass:plotting 7. [spacer]
# INFO:pygenometracks.tracksClass:plotting 8. [genes]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 1.08,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (1.08, -0.08)
# INFO:pygenometracks.tracksClass:plotting 9. [transcripts]
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim 10.28,-0.08
# DEBUG:pygenometracks.tracks.GenomeTrack:ylim (10.28, -0.08)
# INFO:pygenometracks.tracksClass:plotting 10. [x-axis]
